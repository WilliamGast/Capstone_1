# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
data = pd.read_csv('nyc-rolling-sales.csv')
sale = data.copy()
count = data.copy()

cols = data.columns
cols
# Out:
# Index(['Unnamed: 0', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
import seaborn as sns
import scipy.stats as stats

# %%
data['SALE DATE'] = pd.to_datetime(data['SALE DATE'])
data['YEAR'] = data['SALE DATE'].apply(lambda x: x.year)
data['MONTH'] = data['SALE DATE'].apply(lambda x: x.month)
data['DAY'] = data['SALE DATE'].apply(lambda x: x.day)

data = data.drop('SALE DATE', axis=1)

# %%
data['SALE PRICE'] = data['SALE PRICE'].replace(' -  ', np.NaN).astype(np.float)
data = data.dropna(axis=0).reset_index(drop=True)

# %%
data = data.drop(['Unnamed: 0','EASE-MENT','APARTMENT NUMBER'],axis =1)

# %%
for column in ['BOROUGH']:
    data[column] = data[column].astype(int)

# %%
data['GROSS SQUARE FEET'] = data['GROSS SQUARE FEET'].replace(' -  ', np.NaN).astype(np.float)
data = data.dropna(axis=0).reset_index(drop=True)
for column in ['GROSS SQUARE FEET']:
    data[column] = data[column].astype(int)
for column in ['GROSS SQUARE FEET','SALE PRICE']:
    data[column] = data[column].replace(0,np.NaN).astype(np.float)
    data = data.dropna(axis=0).reset_index(drop=True)

# %%
data['SALE PRICE'].min()
# Out:
# 1.0

# %%
boroughs ={1:'Manhattan' , 2:'Bronx' , 3:'Brooklyn', 4:'Queens' , 5:'Staten Island'}
data['BOROUGH'].replace(boroughs,inplace=True)

# %%
data['PRICE PER SQR FOOT'] = data['SALE PRICE'] / data['GROSS SQUARE FEET']
boro
# Out:
#                BLOCK        LOT      ZIP CODE  RESIDENTIAL UNITS  \
# BOROUGH
# 1        1311.879208  55.160396  10029.490099          19.362376
# 2        4135.500854  78.705866  10455.577733           4.360763
# 3        4742.157324  53.338408  11218.913956           2.723529
# 4        8013.055967  54.053439  11391.189023           2.201300
# 5        3366.547591  81.907780  10301.915087           1.355450
#
#          COMMERCIAL UNITS  TOTAL UNITS  GROSS SQUARE FEET   YEAR BUILT  \
# BOROUGH
# 1                2.233663    21.588119       38153.306931  1921.115842
# 2                0.195046     4.554670        5557.876139  1939.250285
# 3                0.189965     2.911765        3793.622491  1928.193426
# 4                0.412981     2.613558        2977.492327  1938.606337
# 5                0.098341     1.452607        2364.205964  1967.471959
#
#          TAX CLASS AT TIME OF SALE    SALE PRICE         YEAR     MONTH  \
# BOROUGH
# 1                         2.335644  1.855808e+07  2016.573267  7.027723
# 2                         1.273918  1.021973e+06  2016.654043  6.536446
# 3                         1.289619  1.508023e+06  2016.655709  6.523875
# 4                         1.144521  9.123055e+05  2016.647229  6.641542
# 5                         1.078199  5.286038e+05  2016.629937  6.556872
#
#                DAY  PRICE PER SQR FOOT
# BOROUGH
# 1        16.668317         1035.078683
# 2        16.831150          240.439395
# 3        16.529066          472.584275
# 4        16.741018          402.049353
# 5        16.181872          314.610444

# %%
boro = data.groupby(['BOROUGH']).mean()
plt.plot(boro['PRICE PER SQR FOOT'])

# %%
plt.plot(data['PRICE PER SQR FOOT'])

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
data.sort_values('PRICE PER SQR FOOT')
# Out:
#              BOROUGH             NEIGHBORHOOD  \
# 8154        Brooklyn       DOWNTOWN-METROTECH
# 2430           Bronx        MELROSE/CONCOURSE
# 28484  Staten Island                TODT HILL
# 755        Manhattan                     SOHO
# 825        Manhattan  UPPER EAST SIDE (59-79)
# ...              ...                      ...
# 617        Manhattan             MIDTOWN EAST
# 340        Manhattan           HARLEM-CENTRAL
# 8137        Brooklyn     DOWNTOWN-FULTON MALL
# 5508        Brooklyn       BEDFORD STUYVESANT
# 10663       Brooklyn               KENSINGTON
#
#                             BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 8154    21 OFFICE BUILDINGS                                            4
# 2430    08 RENTALS - ELEVATOR APARTMENTS                               2
# 28484   33 EDUCATIONAL FACILITIES                                      4
# 755     21 OFFICE BUILDINGS                                            4
# 825     38 ASYLUMS AND HOMES                                           4
# ...                                             ...                  ...
# 617     07 RENTALS - WALKUP APARTMENTS                                2B
# 340     29 COMMERCIAL GARAGES                                          4
# 8137   11A CONDO-RENTALS                                               2
# 5508    29 COMMERCIAL GARAGES                                          4
# 10663   41 TAX CLASS 4 - OTHER                                         4
#
#        BLOCK   LOT BUILDING CLASS AT PRESENT                  ADDRESS  \
# 8154    2058    17                        O6        339 BRIDGE STREET
# 2430    2465    25                        D7       1240 WALTON AVENUE
# 28484    683   301                        W1            MILFORD DRIVE
# 755      599    64                        O6        375 HUDSON STREET
# 825     1468     5                        N9   405 EAST 73RD   STREET
# ...      ...   ...                       ...                      ...
# 617     1369    35                        C4   428 EAST 58TH   STREET
# 340     2013    44                        G5  122-124 WEST 145 STREET
# 8137     165  1001                        RR    236 LIVINGSTON STREET
# 5508    1734    70                        G5       793 BEDFORD AVENUE
# 10663   5322    51                        Z9           72 CATON PLACE
#
#        ZIP CODE  RESIDENTIAL UNITS  ...  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 8154      11201                  0  ...             49122           457966.0
# 2430      10452                162  ...             40046           171044.0
# 28484         0                  0  ...             78672           126468.0
# 755       10014                  0  ...             69096           907938.0
# 825       10021                 77  ...             10217            82600.0
# ...         ...                ...  ...               ...                ...
# 617       10022                  8  ...              2058             4960.0
# 340       10039                  0  ...             13875              322.0
# 8137      11201                  8  ...             18175             5802.0
# 5508      11205                  0  ...             13225              420.0
# 10663     11218                  0  ...             21992              200.0
#
#       YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 8154        1990                          4                              O6
# 2430        1928                          2                              D7
# 28484       1965                          4                              W1
# 755         1987                          4                              O6
# 825         1990                          4                              N9
# ...          ...                        ...                             ...
# 617         1900                          2                              C4
# 340         1972                          4                              G5
# 8137        2009                          2                              RR
# 5508        1995                          4                              G5
# 10663       1931                          4                              Z9
#
#         SALE PRICE  YEAR  MONTH  DAY  PRICE PER SQR FOOT
# 8154           1.0  2017      3   15            0.000002
# 2430           1.0  2017      6   21            0.000006
# 28484          1.0  2016     12    9            0.000008
# 755           10.0  2017      8   14            0.000011
# 825            1.0  2016     11    1            0.000012
# ...            ...   ...    ...  ...                 ...
# 617     86000000.0  2017      3   16        17338.709677
# 340      6750000.0  2016     12   22        20962.732919
# 8137   154250000.0  2016     12   15        26585.660117
# 5508    11375000.0  2017      4   26        27083.333333
# 10663   15194971.0  2017      4    5        75974.855000
#
# [29334 rows x 22 columns]

# %%
def boro_dist(data):
    for name,data in data.groupby('BOROUGH'):
        plt.boxplot(data['PRICE PER SQR FOOT'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-86-50309740e2b8> in <module>
# ----> 1 import pyspark
#       2 def boro_dist(data):
#       3     for name,data in data.groupby('BOROUGH'):
#       4         plt.boxplot(data['PRICE PER SQR FOOT'])
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
#data_without_out
df_bar_1 =data[['BOROUGH', 'PRICE PER SQR FOOT']]
data['z_scores']=stats.zscore(data['PRICE PER SQR FOOT'])
data_without_out = data.copy()
data_without_out.loc[data_without_out['z_scores'].abs()<=3]
data_without_out
# Out:
#              BOROUGH   NEIGHBORHOOD  \
# 0          Manhattan  ALPHABET CITY
# 1          Manhattan  ALPHABET CITY
# 2          Manhattan  ALPHABET CITY
# 3          Manhattan  ALPHABET CITY
# 4          Manhattan  ALPHABET CITY
# ...              ...            ...
# 29329  Staten Island        WOODROW
# 29330  Staten Island        WOODROW
# 29331  Staten Island        WOODROW
# 29332  Staten Island        WOODROW
# 29333  Staten Island        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                2B
# 2      07 RENTALS - WALKUP APARTMENTS                                2A
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# 29329  02 TWO FAMILY DWELLINGS                                        1
# 29330  02 TWO FAMILY DWELLINGS                                        1
# 29331  02 TWO FAMILY DWELLINGS                                        1
# 29332  22 STORE BUILDINGS                                             4
# 29333  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT BUILDING CLASS AT PRESENT                 ADDRESS  ZIP CODE  \
# 0        392    6                        C2            153 AVENUE B     10009
# 1        402   21                        C4     154 EAST 7TH STREET     10009
# 2        404   55                        C2  301 EAST 10TH   STREET     10009
# 3        406   32                        C4            210 AVENUE B     10009
# 4        387  153                        D9     629 EAST 5TH STREET     10009
# ...      ...  ...                       ...                     ...       ...
# 29329   7349   34                        B9           37 QUAIL LANE     10309
# 29330   7349   78                        B9        32 PHEASANT LANE     10309
# 29331   7351   60                        B2        49 PITNEY AVENUE     10309
# 29332   7100   28                        K6   2730 ARTHUR KILL ROAD     10309
# 29333   7105  679                        P9       155 CLAY PIT ROAD     10309
#
#        RESIDENTIAL UNITS  ...  GROSS SQUARE FEET  YEAR BUILT  \
# 0                      5  ...             6440.0        1900
# 1                     10  ...             6794.0        1913
# 2                      6  ...             4615.0        1900
# 3                      8  ...             4226.0        1920
# 4                     24  ...            18523.0        1920
# ...                  ...  ...                ...         ...
# 29329                  2  ...             2575.0        1998
# 29330                  2  ...             2377.0        1998
# 29331                  2  ...             1496.0        1925
# 29332                  0  ...            64117.0        2001
# 29333                  0  ...             2400.0        2006
#
#       TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                             2                              C2   6625000.0
# 1                             2                              C4   3936272.0
# 2                             2                              C2   8000000.0
# 3                             2                              C4   3192840.0
# 4                             2                              D9  16232000.0
# ...                         ...                             ...         ...
# 29329                         1                              B9    450000.0
# 29330                         1                              B9    550000.0
# 29331                         1                              B2    460000.0
# 29332                         4                              K6  11693337.0
# 29333                         4                              P9     69300.0
#
#        YEAR MONTH  DAY  PRICE PER SQR FOOT  z_scores
# 0      2017     7   19         1028.726708  0.941231
# 1      2016     9   23          579.374742  0.257384
# 2      2016    11   17         1733.477790  2.013757
# 3      2016     9   23          755.522953  0.525455
# 4      2016    11    7          876.315932  0.709284
# ...     ...   ...  ...                 ...       ...
# 29329  2016    11   28          174.757282 -0.358383
# 29330  2017     4   21          231.384098 -0.272206
# 29331  2017     7    5          307.486631 -0.156389
# 29332  2016    12   21          182.374986 -0.346790
# 29333  2016    10   27           28.875000 -0.580395
#
# [29334 rows x 23 columns]

# %%
df_bar =data[['BOROUGH', 'PRICE PER SQR FOOT',]].groupby(by='BOROUGH').mean().sort_values(by='PRICE PER SQR FOOT', ascending=True).reset_index()

plt.figure(figsize=(12,6))
g = sns.boxplot(x = 'BOROUGH',y = 'PRICE PER SQR FOOT',data = data_without_out)
g.set(ylim=(0,3000))
# Out:
# [(0, 3000)]

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x = 'BUILDING CLASS AT TIME OF SALE',y = 'PRICE PER SQR FOOT',data = data_without_out)
g

# %%
data_without_out.groupby
# Out:
#              BOROUGH   NEIGHBORHOOD  \
# 0          Manhattan  ALPHABET CITY
# 1          Manhattan  ALPHABET CITY
# 2          Manhattan  ALPHABET CITY
# 3          Manhattan  ALPHABET CITY
# 4          Manhattan  ALPHABET CITY
# ...              ...            ...
# 29329  Staten Island        WOODROW
# 29330  Staten Island        WOODROW
# 29331  Staten Island        WOODROW
# 29332  Staten Island        WOODROW
# 29333  Staten Island        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                2B
# 2      07 RENTALS - WALKUP APARTMENTS                                2A
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# 29329  02 TWO FAMILY DWELLINGS                                        1
# 29330  02 TWO FAMILY DWELLINGS                                        1
# 29331  02 TWO FAMILY DWELLINGS                                        1
# 29332  22 STORE BUILDINGS                                             4
# 29333  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT BUILDING CLASS AT PRESENT                 ADDRESS  ZIP CODE  \
# 0        392    6                        C2            153 AVENUE B     10009
# 1        402   21                        C4     154 EAST 7TH STREET     10009
# 2        404   55                        C2  301 EAST 10TH   STREET     10009
# 3        406   32                        C4            210 AVENUE B     10009
# 4        387  153                        D9     629 EAST 5TH STREET     10009
# ...      ...  ...                       ...                     ...       ...
# 29329   7349   34                        B9           37 QUAIL LANE     10309
# 29330   7349   78                        B9        32 PHEASANT LANE     10309
# 29331   7351   60                        B2        49 PITNEY AVENUE     10309
# 29332   7100   28                        K6   2730 ARTHUR KILL ROAD     10309
# 29333   7105  679                        P9       155 CLAY PIT ROAD     10309
#
#        RESIDENTIAL UNITS  ...  GROSS SQUARE FEET  YEAR BUILT  \
# 0                      5  ...             6440.0        1900
# 1                     10  ...             6794.0        1913
# 2                      6  ...             4615.0        1900
# 3                      8  ...             4226.0        1920
# 4                     24  ...            18523.0        1920
# ...                  ...  ...                ...         ...
# 29329                  2  ...             2575.0        1998
# 29330                  2  ...             2377.0        1998
# 29331                  2  ...             1496.0        1925
# 29332                  0  ...            64117.0        2001
# 29333                  0  ...             2400.0        2006
#
#       TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                             2                              C2   6625000.0
# 1                             2                              C4   3936272.0
# 2                             2                              C2   8000000.0
# 3                             2                              C4   3192840.0
# 4                             2                              D9  16232000.0
# ...                         ...                             ...         ...
# 29329                         1                              B9    450000.0
# 29330                         1                              B9    550000.0
# 29331                         1                              B2    460000.0
# 29332                         4                              K6  11693337.0
# 29333                         4                              P9     69300.0
#
#        YEAR MONTH  DAY  PRICE PER SQR FOOT  z_scores
# 0      2017     7   19         1028.726708  0.941231
# 1      2016     9   23          579.374742  0.257384
# 2      2016    11   17         1733.477790  2.013757
# 3      2016     9   23          755.522953  0.525455
# 4      2016    11    7          876.315932  0.709284
# ...     ...   ...  ...                 ...       ...
# 29329  2016    11   28          174.757282 -0.358383
# 29330  2017     4   21          231.384098 -0.272206
# 29331  2017     7    5          307.486631 -0.156389
# 29332  2016    12   21          182.374986 -0.346790
# 29333  2016    10   27           28.875000 -0.580395
#
# [29334 rows x 23 columns]
